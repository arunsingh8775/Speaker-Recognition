# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import librosa.display
import IPython.display
import os
import librosa 
from scipy.io import wavfile as wav
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # **Data**

# %% [markdown]
# The data is collected from LibriSpeech
#
# ---

# %% [markdown]
# # **Plot of Audio**

# %%
x, fs = librosa.load('/content/drive/My Drive/Audio Data/person1/Copy of 84-121123-0002.flac', res_type='kaiser_fast')
librosa.display.waveplot(x, sr=fs)
SAMPLE_RATE = 44100

# %%
IPython.display.Audio(x, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **MFCC Feature**

# %%
def extract_features(name):
    b, _ = librosa.core.load(name, sr = SAMPLE_RATE)
    assert _ == SAMPLE_RATE
    try:
        mfcc = librosa.feature.mfcc(b, sr = SAMPLE_RATE, n_mfcc=20)
        return np.array(np.hstack((np.mean(mfcc, axis=1), np.std(mfcc, axis=1))))
    except:
        print('bad file')
        return np.array([0]*40)

# %%
 df = extract_features("/content/drive/My Drive/Audio Data/person1/Copy of 84-121123-0002.flac")
 df
# Out:
# array([-3.75043534e+02,  1.47979616e+02, -6.20550379e+00,  3.03910670e+01,
#         1.71370320e+01, -8.34698338e+00,  1.58000269e+01, -3.77309348e+00,
#        -1.91218784e+01, -7.55696427e+00, -4.61415893e+00,  1.66967384e+00,
#        -6.00610588e-01, -3.00466490e+00,  1.91523525e+00, -4.02100903e-01,
#         2.39941398e-01, -5.16483711e+00, -9.64542125e+00, -1.42227997e+00,
#         6.30923848e+01,  4.69620600e+01,  4.01362400e+01,  2.90608446e+01,
#         2.15902375e+01,  1.69907918e+01,  1.98453698e+01,  1.35843028e+01,
#         1.17982205e+01,  1.42827363e+01,  1.16681157e+01,  1.02708264e+01,
#         8.53458292e+00,  8.77321939e+00,  9.83328379e+00,  7.28789729e+00,
#         6.75136982e+00,  8.57808721e+00,  7.10860061e+00,  6.65189880e+00])

# %%
df.shape
# Out:
# (40,)

# %% [markdown]
# # **Plot of mfcc Feature**

# %%
import matplotlib.pyplot as plt
plt.plot(df)
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# # **Visualize the MFCC series in time and frequency domain**

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time', y_axis='mel')

# %%
x = []
y = []

for filename in os.listdir('/content/drive/My Drive/Audio Data/person1'):
    df = extract_features("/content/drive/My Drive/Audio Data/person1/" + filename)
    x.append(df)
    y.append(1)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person2'):
    df = extract_features("/content/drive/My Drive/Audio Data/person2/" + filename)
    x.append(df)
    y.append(2)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person3'):
    df = extract_features("/content/drive/My Drive/Audio Data/person3/" + filename)
    x.append(df)
    y.append(3)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person4'):
    df = extract_features("/content/drive/My Drive/Audio Data/person4/" + filename)
    x.append(df)
    y.append(4)


for filename in os.listdir('/content/drive/My Drive/Audio Data/person5'):
    df = extract_features("/content/drive/My Drive/Audio Data/person5/" + filename)
    x.append(df)
    y.append(5)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person6'):
    df = extract_features("/content/drive/My Drive/Audio Data/person6/" + filename)
    x.append(df)
    y.append(6)


for filename in os.listdir('/content/drive/My Drive/Audio Data/person7'):
    df = extract_features("/content/drive/My Drive/Audio Data/person7/" + filename)
    x.append(df)
    y.append(7)


for filename in os.listdir('/content/drive/My Drive/Audio Data/person8'):
    df = extract_features("/content/drive/My Drive/Audio Data/person8/" + filename)
    x.append(df)
    y.append(8)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person9'):
    df = extract_features("/content/drive/My Drive/Audio Data/person9/" + filename)
    x.append(df)
    y.append(9)



for filename in os.listdir('/content/drive/My Drive/Audio Data/person10'):
    df = extract_features("/content/drive/My Drive/Audio Data/person10/" + filename)
    x.append(df)
    y.append(10)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person11'):
    df = extract_features("/content/drive/My Drive/Audio Data/person11/" + filename)
    x.append(df)
    y.append(11)


for filename in os.listdir('/content/drive/My Drive/Audio Data/person12'):
    df = extract_features("/content/drive/My Drive/Audio Data/person12/" + filename)
    x.append(df)
    y.append(12)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person13'):
    df = extract_features("/content/drive/My Drive/Audio Data/person13/" + filename)
    x.append(df)
    y.append(13)



for filename in os.listdir('/content/drive/My Drive/Audio Data/person14'):
    df = extract_features("/content/drive/My Drive/Audio Data/person14/" + filename)
    x.append(df)
    y.append(14)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person15'):
    df = extract_features("/content/drive/My Drive/Audio Data/person15/" + filename)
    x.append(df)
    y.append(15)




for filename in os.listdir('/content/drive/My Drive/Audio Data/person16'):
    df = extract_features("/content/drive/My Drive/Audio Data/person16/" + filename)
    x.append(df)
    y.append(16)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person17'):
    df = extract_features("/content/drive/My Drive/Audio Data/person17/" + filename)
    x.append(df)
    y.append(17)



for filename in os.listdir('/content/drive/My Drive/Audio Data/person18'):
    df = extract_features("/content/drive/My Drive/Audio Data/person18/" + filename)
    x.append(df)
    y.append(18)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person19'):
    df = extract_features("/content/drive/My Drive/Audio Data/person19/" + filename)
    x.append(df)
    y.append(19)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person20'):
    df = extract_features("/content/drive/My Drive/Audio Data/person20/" + filename)
    x.append(df)
    y.append(20)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person21'):
    df = extract_features("/content/drive/My Drive/Audio Data/person21/" + filename)
    x.append(df)
    y.append(21)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person22'):
    df = extract_features("/content/drive/My Drive/Audio Data/person22/" + filename)
    x.append(df)
    y.append(22)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person23'):
    df = extract_features("/content/drive/My Drive/Audio Data/person23/" + filename)
    x.append(df)
    y.append(23)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person35'):
    df = extract_features("/content/drive/My Drive/Audio Data/person35/" + filename)
    x.append(df)
    y.append(35)

for filename in os.listdir('/content/drive/My Drive/Audio Data/person36'):
    df = extract_features("/content/drive/My Drive/Audio Data/person36/" + filename)
    x.append(df)
    y.append(36)
    

for filename in os.listdir('/content/drive/My Drive/Audio Data/person37'):
    df = extract_features("/content/drive/My Drive/Audio Data/person37/" + filename)
    x.append(df)
    y.append(37)

# %%
#.......
data = pd.DataFrame(x)
data.to_csv("/content/drive/My Drive/Audio Data/data.csv",index=False)

# %%
data = pd.read_csv("/content/drive/My Drive/Audio Data/data.csv")

# %%
#........
label = pd.DataFrame(y)
label.to_csv("/content/drive/My Drive/Audio Data/label.csv",index=False)

# %%
label = pd.read_csv("/content/drive/My Drive/Audio Data/label.csv")

# %%
data['label'] = label
data
# Out:
#                0           1          2  ...        38        39  label
# 0    -381.458108  149.981878  -6.736127  ...  6.612869  6.693302      1
# 1    -389.848961  155.743095 -14.374327  ...  7.248204  6.920647      1
# 2    -386.540212  150.677043  -9.564620  ...  7.150719  5.736190      1
# 3    -404.457689  131.222990 -12.724212  ...  7.361483  6.450212      1
# 4    -428.232387  158.673219 -21.001281  ...  6.604990  6.984197      1
# ...          ...         ...        ...  ...       ...       ...    ...
# 1684 -387.967109  126.608035  -6.743167  ...  5.757868  5.568107     37
# 1685 -418.799773  114.176483  -1.450920  ...  7.556181  7.249696     37
# 1686 -452.021984  131.818665  -8.364589  ...  6.936246  6.673198     37
# 1687 -354.849806  111.457635 -17.083974  ...  6.590607  6.318589     37
# 1688 -431.363459   94.221604   2.974231  ...  6.403593  6.933087     37
#
# [1689 rows x 41 columns]

# %%
data.shape
# Out:
# (1689, 41)

# %%
X = data.iloc[:,:-1]
Y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4, random_state = 42)

# %% [markdown]
# # **Normalisation of Data**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.size//40
# Out:
# 1013

# %%
X_test.size//40
# Out:
# 676

# %% [markdown]
# # **SVM**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

from sklearn.metrics import classification_report,  accuracy_score

result1 = classification_report(y_test, y_pred)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100)
# Out:
# Accuracy: 83.13609467455622

# %% [markdown]
# # **Random Forest**

# %%
from sklearn import svm 
rfc = svm.SVC(kernel='linear', C=0.01)
rfc.fit(X_train, y_train)
print("Accuracy:",rfc.score(X_test, y_test)*100)
# Out:
# Accuracy: 87.72189349112426
